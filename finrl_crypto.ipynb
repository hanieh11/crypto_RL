# %%
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-t1dj_srd
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-t1dj_srd
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit e523ca0519288b3117f014e19163fe4c514d20ea
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-ggc0pffb/elegantrl_021ff78a30904c1fac209d8c627fc83c
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-ggc0pffb/elegantrl_021ff78a30904c1fac209d8c627fc83c
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 47831d796eac39cd14dc75bad1f21db1d1d6ad66
#   Preparing metadata (setup.py) ... done
# Collecting alpaca-trade-api<4,>=3 (from finrl==0.3.6)
#   Downloading alpaca_trade_api-3.2.0-py3-none-any.whl.metadata (29 kB)
# Collecting ccxt<4,>=3 (from finrl==0.3.6)
#   Downloading ccxt-3.1.60-py2.py3-none-any.whl.metadata (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.7/108.7 kB 8.8 MB/s eta 0:00:00
# Collecting exchange-calendars<5,>=4 (from finrl==0.3.6)
#   Downloading exchange_calendars-4.5.7-py3-none-any.whl.metadata (37 kB)
# Collecting jqdatasdk<2,>=1 (from finrl==0.3.6)
#   Downloading jqdatasdk-1.9.6-py3-none-any.whl.metadata (5.8 kB)
# Collecting pyfolio<0.10,>=0.9 (from finrl==0.3.6)
#   Downloading pyfolio-0.9.2.tar.gz (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyportfolioopt<2,>=1 (from finrl==0.3.6)
#   Downloading pyportfolioopt-1.5.5-py3-none-any.whl.metadata (23 kB)
# Collecting ray<3,>=2 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading ray-2.37.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (1.5.2)
# Collecting stable-baselines3>=2.0.0a5 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading stable_baselines3-2.4.0a7-py3-none-any.whl.metadata (5.1 kB)
# Collecting stockstats<0.6,>=0.5 (from finrl==0.3.6)
#   Downloading stockstats-0.5.4-py2.py3-none-any.whl.metadata (26 kB)
# Collecting wrds<4,>=3 (from finrl==0.3.6)
#   Downloading wrds-3.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (0.2.44)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.2.2)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.4)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.32.3)
# Collecting urllib3<2,>1.24 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.8.0)
# Collecting websockets<11,>=9.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting msgpack==1.0.3 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.10.10)
# Collecting PyYAML==6.0.1 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting deprecation==2.1.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (24.1)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (75.1.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (2024.8.30)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (43.0.1)
# Collecting aiodns>=1.1.1 (from ccxt<4,>=3->finrl==0.3.6)
#   Downloading aiodns-3.2.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: yarl>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (1.15.2)
# Collecting pyluach (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Downloading pyluach-2.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2024.2)
# Collecting korean-lunar-calendar (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (2.0.36)
# Collecting pymysql>=0.7.6 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting thriftpy2!=0.5.1,>=0.3.9 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading thriftpy2-0.5.2.tar.gz (782 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.3/782.3 kB 43.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.7.1)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (2024.2)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.13.1)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.13.2)
# Collecting empyrical>=0.5.0 (from pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Downloading empyrical-0.5.5.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /usr/local/lib/python3.10/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.5.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (3.16.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (4.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (3.20.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (1.4.1)
# Collecting tensorboardX>=1.9 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (16.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2024.6.1)
# Collecting aiohttp-cors (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting py-spy>=0.2.0 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Collecting opencensus (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.9.2)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.21.0)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (7.0.5)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading virtualenv-20.27.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.64.1)
# Collecting memray (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading memray-1.14.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.5.0)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.4.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.66.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.9.2)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (10.4.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting packaging (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psycopg2-binary<2.10,>=2.9 (from wrds<4,>=3->finrl==0.3.6)
#   Downloading psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting scipy>=0.14.0 (from pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (3.17.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Collecting th (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6)
#   Downloading th-0.4.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting pycares>=4.0.0 (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6)
#   Downloading pycares-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (2.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (6.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (4.0.3)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 26.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.6)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.17.1)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.7.post3)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.14)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.9.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.7)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.10/dist-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Collecting jedi>=0.16 (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.10)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.4)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.10/dist-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.0.11)
# Collecting ply<4.0,>=3.4 (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.4)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl>=1.7.2->ccxt<4,>=3->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (0.20.0)
# Collecting textual>=0.41.0 (from memray->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading textual-0.83.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open->ray[default,tune]<3,>=2->finrl==0.3.6) (1.16.0)
# Collecting niltype<2.0,>=0.3 (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6)
#   Downloading niltype-1.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (6.4.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.65.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.24.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.27.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7.post4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.13)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (4.9)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default,tune]<3,>=2->finrl==0.3.6) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.2)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default,tune]<3,>=2->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.6.1)
# Downloading alpaca_trade_api-3.2.0-py3-none-any.whl (34 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.7/323.7 kB 24.2 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 45.4 MB/s eta 0:00:00
# Downloading ccxt-3.1.60-py2.py3-none-any.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 87.6 MB/s eta 0:00:00
# Downloading exchange_calendars-4.5.7-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.7/196.7 kB 15.5 MB/s eta 0:00:00
# Downloading jqdatasdk-1.9.6-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 6.3 MB/s eta 0:00:00
# Downloading pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 5.6 MB/s eta 0:00:00
# Downloading ray-2.37.0-cp310-cp310-manylinux2014_x86_64.whl (65.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 MB 10.0 MB/s eta 0:00:00
# Downloading stable_baselines3-2.4.0a7-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.9/182.9 kB 13.9 MB/s eta 0:00:00
# Downloading stockstats-0.5.4-py2.py3-none-any.whl (21 kB)
# Downloading wrds-3.2.0-py3-none-any.whl (13 kB)
# Downloading aiodns-3.2.0-py3-none-any.whl (5.7 kB)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 48.2 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.3 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.9 MB/s eta 0:00:00
# Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 79.2 MB/s eta 0:00:00
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.2 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 23.9 MB/s eta 0:00:00
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.9 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 11.8 MB/s eta 0:00:00
# Downloading virtualenv-20.27.0-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 73.8 MB/s eta 0:00:00
# Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.6 MB/s eta 0:00:00
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 13.3 MB/s eta 0:00:00
# Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Downloading memray-1.14.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 101.1 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 10.3 MB/s eta 0:00:00
# Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Downloading th-0.4.1-py3-none-any.whl (12 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 59.7 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 30.3 MB/s eta 0:00:00
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.0 MB/s eta 0:00:00
# Downloading niltype-1.0.2-py3-none-any.whl (5.3 kB)
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.3 MB/s eta 0:00:00
# Downloading pycares-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 21.5 MB/s eta 0:00:00
# Downloading textual-0.83.0-py3-none-any.whl (600 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 600.4/600.4 kB 34.5 MB/s eta 0:00:00
# Building wheels for collected packages: finrl, pyfolio, elegantrl, empyrical, thriftpy2, AutoROM.accept-rom-license
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.6-py3-none-any.whl size=4691726 sha256=ec45ee94578849af5642683a93c138a0730996facdca6d77c54b597afb4f66e9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p6zmm9i9/wheels/72/3b/1a/0fc805a8cc65ecd5bfe4f74a3c586b6075678b8ba53fd8f749
#   Building wheel for pyfolio (setup.py) ... done
#   Created wheel for pyfolio: filename=pyfolio-0.9.2-py3-none-any.whl size=88656 sha256=35850e782b5414a0c50305613d22fb88f7fdc591854eefce4e5bbd48648b79d6
#   Stored in directory: /root/.cache/pip/wheels/71/38/bc/e53700cfd8b0ad6b539d2fbaaf060ed8a299e7622a5b86ef42
#   Building wheel for elegantrl (setup.py) ... done
#   Created wheel for elegantrl: filename=ElegantRL-0.3.10-py3-none-any.whl size=385203 sha256=e926bb790c636254056150c58980111977f6d66ebb6e4322dda31b8c4af04279
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p6zmm9i9/wheels/c0/51/a5/b05f165548221bc570f7223babd33e2992fa873cdcebe2d229
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39753 sha256=4c1b7f71e3bdae7dfe58d90facecf862d5a38621e9ee5f55422c8e9741caf63b
#   Stored in directory: /root/.cache/pip/wheels/0e/2e/f2/d6d2d9a1eb8fbbd9949bb5d4c00f753e3b74e5bd7ed10b1d36
#   Building wheel for thriftpy2 (pyproject.toml) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.5.2-cp310-cp310-linux_x86_64.whl size=1749965 sha256=7b9890fad6dd4bfbdbfd776c79d7c638550c3244a8c339d417beba6d5bdcc781
#   Stored in directory: /root/.cache/pip/wheels/90/28/5f/279788e86e2eaccb3edc73bde9c815a9527602739a56344ff7
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=9ca36b608bffdeb75e3fdbfc8c0c6669e2cac91da549f76f070414193e761c6a
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built finrl pyfolio elegantrl empyrical thriftpy2 AutoROM.accept-rom-license
# Installing collected packages: py-spy, ply, opencensus-context, msgpack, korean-lunar-calendar, farama-notifications, distlib, colorful, websockets, virtualenv, urllib3, thriftpy2, scipy, PyYAML, pymysql, pyluach, psycopg2-binary, packaging, niltype, jedi, gymnasium, ale-py, th, tensorboardX, shimmy, pycares, deprecation, wrds, stockstats, stable-baselines3, jqdatasdk, exchange-calendars, elegantrl, AutoROM.accept-rom-license, autorom, aiodns, textual, ray, opencensus, empyrical, ccxt, alpaca-trade-api, aiohttp-cors, pyportfolioopt, pyfolio, memray, finrl
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.1.0
#     Uninstalling msgpack-1.1.0:
#       Successfully uninstalled msgpack-1.1.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
# Successfully installed AutoROM.accept-rom-license-0.6.1 PyYAML-6.0.1 aiodns-3.2.0 aiohttp-cors-0.7.0 ale-py-0.8.1 alpaca-trade-api-3.2.0 autorom-0.6.1 ccxt-3.1.60 colorful-0.5.6 deprecation-2.1.0 distlib-0.3.9 elegantrl-0.3.10 empyrical-0.5.5 exchange-calendars-4.5.7 farama-notifications-0.0.4 finrl-0.3.6 gymnasium-0.29.1 jedi-0.19.1 jqdatasdk-1.9.6 korean-lunar-calendar-0.3.1 memray-1.14.0 msgpack-1.0.3 niltype-1.0.2 opencensus-0.11.4 opencensus-context-0.1.3 packaging-23.2 ply-3.11 psycopg2-binary-2.9.10 py-spy-0.3.14 pycares-4.4.0 pyfolio-0.9.2 pyluach-2.2.0 pymysql-1.1.1 pyportfolioopt-1.5.5 ray-2.37.0 scipy-1.12.0 shimmy-1.3.0 stable-baselines3-2.4.0a7 stockstats-0.5.4 tensorboardX-2.6.2.2 textual-0.83.0 th-0.4.1 thriftpy2-0.5.2 urllib3-1.26.20 virtualenv-20.27.0 websockets-10.4 wrds-3.2.0

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime

from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.config import INDICATORS
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/util.py:55: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs; see https://jax.readthedocs.io/en/latest/aot.html. For example, replace xla_computation(f)(*xs) with jit(f).lower(*xs).compiler_ir('hlo'). See CHANGELOG.md for 0.4.30 for more examples.
#   from jax import xla_computation as _xla_computation

# %% [markdown]
# # 1. Data Wrangle

# %%
TRAIN_START_DATE = '2020-01-01'
TRAIN_END_DATE = '2020-12-31'
TRADE_START_DATE = '2021-09-01'
TRADE_END_DATE = '2021-12-31'

symbols = [
    'BTC-USD',
    'ETH-USD',
    'BNB-USD',
    'ADA-USD',
    'XRP-USD',
    'SOL-USD',
    'BCH-USD'
]

# %%
#Future improvement would be to use Alpaca/Binance

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader

df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = symbols).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (5010, 8)

# %%
df_raw.head()
# Out:
#          date         open         high          low        close  \
# 0  2020-01-01     0.032832     0.033813     0.032704     0.033458
# 1  2020-01-01   204.671295   208.077515   203.205154   204.397537
# 2  2020-01-01    13.730962    13.873946    13.654942    13.689083
# 3  2020-01-01  7194.892090  7254.330566  7174.944336  7200.174316
# 4  2020-01-01   129.630661   132.835358   129.198288   130.802002
#
#         volume      tic  day
# 0     22948374  ADA-USD    2
# 1   1456113692  BCH-USD    2
# 2    172980718  BNB-USD    2
# 3  18565664997  BTC-USD    2
# 4   7935230330  ETH-USD    2

# %% [markdown]
# ## Preprocess Data

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature=False)

processed = fe.preprocess_data(df_raw)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Successfully added technical indicators
# Shape of DataFrame:  (503, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#             date       open       high        low      close      volume  \
# 341   2020-03-24   0.157574   0.163493   0.156824   0.162255  2155981658
# 314   2020-03-18  10.036181  10.236060   9.760224  10.119137   264539835
# 2939  2021-12-09   0.862143   0.930541   0.835129   0.861272  4555815213
# 266   2020-03-06  20.827026  21.701672  20.783857  21.288389   449180749
# 641   2020-06-04   0.203719   0.206494   0.201864   0.204982  1368430496
#
#           tic  day      macd    boll_ub    boll_lb     rsi_30      cci_30  \
# 341   XRP-USD    1 -0.022563   0.249352   0.104247  40.831615  -64.161300
# 314   BNB-USD    2 -2.947726  24.890159   6.771835  35.018705 -138.111949
# 2939  XRP-USD    3 -0.069225   1.135910   0.772890  40.931107  -93.087514
# 266   BNB-USD    4 -0.321443  24.521149  17.662066  54.757452  -29.087014
# 641   XRP-USD    3  0.000560   0.209226   0.192897  51.247052   19.353707
#
#           dx_30  close_30_sma  close_60_sma        vix  turbulence
# 341   34.569071      0.197733      0.234553  61.669998    0.000000
# 314   71.633373     17.751043     19.060886  76.449997    0.000000
# 2939  42.961376      1.018722      1.072581  21.580000    2.298725
# 266    0.535759     22.126328     19.631421  41.939999    0.000000
# 641   19.893121      0.202849      0.200716  25.809999    0.000000

# %%
import itertools

list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).
                 astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sample(5)
# Out:
#             date      tic        open        high         low       close  \
# 3266  2021-06-29  BNB-USD  289.919128  315.439331  289.221161  300.211548
# 808   2020-05-15  ETH-USD  202.955399  203.566391  193.755676  195.622665
# 877   2020-05-27  BCH-USD  227.278503  234.030792  226.866913  233.520950
# 953   2020-06-08  XRP-USD    0.203426    0.204178    0.201667    0.203771
# 1882  2020-11-10  ETH-USD  444.166382  453.758362  439.600128  449.679626
#
#             volume  day       macd     boll_ub     boll_lb     rsi_30  \
# 3266  1.946428e+09  1.0 -26.840167  393.434726  250.594171  44.430392
# 808   1.660234e+10  4.0   4.147015  222.633726  184.914356  52.589388
# 877   3.107897e+09  2.0  -3.463298  259.386123  217.625276  47.553633
# 953   1.042709e+09  0.0   0.000586    0.209410    0.193108  50.781265
# 1882  1.209038e+10  1.0  17.566573  459.289341  361.315451  59.830419
#
#           cci_30      dx_30  close_30_sma  close_60_sma        vix  turbulence
# 3266  -78.820144  30.184750    341.639229    420.444527  16.020000    1.143986
# 808    10.436115   2.211631    196.174037    169.597588  31.889999    0.000000
# 877   -86.468208  10.258313    242.714718    238.574233  27.620001    0.000000
# 953    50.306192  11.133166      0.200969      0.201178  25.809999    0.000000
# 1882  167.272639  46.126883    399.548564    379.523842  24.799999    0.000000

# %% [markdown]
# ## Data Split and Save

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)

print(len(train))
print(len(trade))
# Out:
# 1512
# 498

# %%
train.to_csv('./train.csv')
trade.to_csv('./trade.csv')

print(f"train.shape: {train.shape}")
print(f"trade.shape: {trade.shape}")
# Out:
# train.shape: (1512, 18)
# trade.shape: (498, 18)

# %% [markdown]
# # 2. Train, Test, & Make Env
# ## Design Env

# %%
crypto_dimension = len(processed_full.tic.unique()) # the number of cryptocurrencies
state_space = 1+ 2*crypto_dimension + len(INDICATORS)*crypto_dimension
print(f"Crypto dimension: {crypto_dimension}, State space: {state_space}")
# Out:
# Crypto dimension: 6, State space: 61

# %% [markdown]
# We're using stock env of FinRl due to many packaging issues in the crypto env and the similar behaviour and outdome of both on RL terms

# %%
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

buy_cost_list = sell_cost_list = [0.001] * crypto_dimension   # the transaction costs for buying and selling each cryptocurrency
num_crypto_shares = [0] * crypto_dimension

env_kwargs = {
    "hmax": 100,  # maximum number of steps per episode
    "initial_amount": 1000000,  # initial investment amount
    "num_stock_shares": num_crypto_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": crypto_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": crypto_dimension,
    "reward_scaling": 1e-4
}

e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env() #vectorizing the initialized env
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ## initialize agent & train

# %%
from finrl.agents.stablebaselines3.models import DRLAgent

agent = DRLAgent(env = env_train)

#set the corresponding values to True for the algorithms that you want to use
if_using_sac = False
if_using_ddpg = False
if_using_ppo = True
if_using_a2c = True
if_using_td3 = False

# %%
from stable_baselines3.common.logger import configure
from finrl.config import TRAINED_MODEL_DIR, RESULTS_DIR

model_a2c = agent.get_model("a2c")
if if_using_a2c:
  #set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])    #set ups three types of log (console csv and tensorboard)
  #set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c,
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 317       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -8.5      |
# |    explained_variance | -0.044    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 92.8      |
# |    reward             | 6.9659696 |
# |    std                | 0.997     |
# |    value_loss         | 173       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 317       |
# |    iterations         | 200       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -8.53     |
# |    explained_variance | -0.0304   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -71.3     |
# |    reward             | 2.5804245 |
# |    std                | 1         |
# |    value_loss         | 106       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 300       |
# |    iterations         | 300       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -8.52     |
# |    explained_variance | -0.00484  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -45       |
# |    reward             | 14.857772 |
# |    std                | 1         |
# |    value_loss         | 86.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 285        |
# |    iterations         | 400        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -8.52      |
# |    explained_variance | 0.00472    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -29.6      |
# |    reward             | -13.603635 |
# |    std                | 1          |
# |    value_loss         | 249        |
# --------------------------------------
# day: 251, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 2053853.94
# total_reward: 1053853.94
# total_cost: 35393.19
# total_trades: 1415
# Sharpe: 1.312
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 294       |
# |    iterations         | 500       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -8.52     |
# |    explained_variance | -0.00255  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 366       |
# |    reward             | 4.1247053 |
# |    std                | 1         |
# |    value_loss         | 1.82e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 302        |
# |    iterations         | 600        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -8.51      |
# |    explained_variance | 0.00155    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 26.1       |
# |    reward             | -15.886328 |
# |    std                | 0.999      |
# |    value_loss         | 18.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 306       |
# |    iterations         | 700       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -8.51     |
# |    explained_variance | -0.000543 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 72.8      |
# |    reward             | -4.001595 |
# |    std                | 1         |
# |    value_loss         | 129       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 310       |
# |    iterations         | 800       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -8.53     |
# |    explained_variance | -0.031    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 307       |
# |    reward             | 6.9608765 |
# |    std                | 1         |
# |    value_loss         | 1.12e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 313        |
# |    iterations         | 900        |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -8.52      |
# |    explained_variance | 0.035      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -40.4      |
# |    reward             | -4.5920906 |
# |    std                | 1          |
# |    value_loss         | 26.1       |
# --------------------------------------
# day: 251, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 2860469.60
# total_reward: 1860469.60
# total_cost: 52612.81
# total_trades: 1266
# Sharpe: 1.727
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 1000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -8.52    |
# |    explained_variance | -0.00588 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 38.4     |
# |    reward             | 2.453605 |
# |    std                | 1        |
# |    value_loss         | 92.2     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 311       |
# |    iterations         | 1100      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -8.52     |
# |    explained_variance | -0.00148  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 89.1      |
# |    reward             | -7.839485 |
# |    std                | 1         |
# |    value_loss         | 80.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 302       |
# |    iterations         | 1200      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -8.54     |
# |    explained_variance | -0.00199  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 13.4      |
# |    reward             | 11.024904 |
# |    std                | 1.01      |
# |    value_loss         | 48        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 305        |
# |    iterations         | 1300       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -8.56      |
# |    explained_variance | 0.00891    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 61.8       |
# |    reward             | -4.8633523 |
# |    std                | 1.01       |
# |    value_loss         | 56.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 308       |
# |    iterations         | 1400      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -8.55     |
# |    explained_variance | -0.00149  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -14.4     |
# |    reward             | 11.366261 |
# |    std                | 1.01      |
# |    value_loss         | 9.55      |
# -------------------------------------
# day: 251, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 3220413.51
# total_reward: 2220413.51
# total_cost: 34222.09
# total_trades: 1232
# Sharpe: 1.849
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 310        |
# |    iterations         | 1500       |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -8.57      |
# |    explained_variance | -0.00158   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 81         |
# |    reward             | -7.0790043 |
# |    std                | 1.01       |
# |    value_loss         | 97.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 312        |
# |    iterations         | 1600       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -8.56      |
# |    explained_variance | -0.00104   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -193       |
# |    reward             | 0.07481212 |
# |    std                | 1.01       |
# |    value_loss         | 727        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 312       |
# |    iterations         | 1700      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -8.58     |
# |    explained_variance | -1e-05    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 42.6      |
# |    reward             | 10.852384 |
# |    std                | 1.01      |
# |    value_loss         | 30.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 314        |
# |    iterations         | 1800       |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -8.57      |
# |    explained_variance | -7.98e-05  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -0.0442    |
# |    reward             | -0.5050168 |
# |    std                | 1.01       |
# |    value_loss         | 7.82       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 313      |
# |    iterations         | 1900     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -8.56    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -61.7    |
# |    reward             | 1.93076  |
# |    std                | 1.01     |
# |    value_loss         | 72.3     |
# ------------------------------------
# day: 251, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 2085408.01
# total_reward: 1085408.01
# total_cost: 84526.81
# total_trades: 1351
# Sharpe: 1.634
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 308        |
# |    iterations         | 2000       |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -8.54      |
# |    explained_variance | 0.000343   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -9.07      |
# |    reward             | -2.9718075 |
# |    std                | 1          |
# |    value_loss         | 11.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 307       |
# |    iterations         | 2100      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -8.55     |
# |    explained_variance | -0.000614 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -44.4     |
# |    reward             | 5.6802387 |
# |    std                | 1.01      |
# |    value_loss         | 31.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 308       |
# |    iterations         | 2200      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -8.57     |
# |    explained_variance | 0.00108   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -31.9     |
# |    reward             | 1.0808542 |
# |    std                | 1.01      |
# |    value_loss         | 16        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 310        |
# |    iterations         | 2300       |
# |    time_elapsed       | 37         |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -8.59      |
# |    explained_variance | -0.000849  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -3.35      |
# |    reward             | 0.11165439 |
# |    std                | 1.01       |
# |    value_loss         | 4.65       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 311        |
# |    iterations         | 2400       |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -8.54      |
# |    explained_variance | -0.00126   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | -16.3      |
# |    reward             | 0.01367686 |
# |    std                | 1.01       |
# |    value_loss         | 3.71       |
# --------------------------------------
# day: 251, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 2671387.24
# total_reward: 1671387.24
# total_cost: 135291.83
# total_trades: 1210
# Sharpe: 1.947
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 2500     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -8.55    |
# |    explained_variance | 0.000415 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 29.9     |
# |    reward             | 5.93154  |
# |    std                | 1.01     |
# |    value_loss         | 17.9     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 313         |
# |    iterations         | 2600        |
# |    time_elapsed       | 41          |
# |    total_timesteps    | 13000       |
# | train/                |             |
# |    entropy_loss       | -8.6        |
# |    explained_variance | -8.92e-05   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2599        |
# |    policy_loss        | 86          |
# |    reward             | -0.45593444 |
# |    std                | 1.02        |
# |    value_loss         | 176         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 315       |
# |    iterations         | 2700      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -8.58     |
# |    explained_variance | -0.00305  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | 19.1      |
# |    reward             | 1.8434455 |
# |    std                | 1.01      |
# |    value_loss         | 5.71      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 311        |
# |    iterations         | 2800       |
# |    time_elapsed       | 44         |
# |    total_timesteps    | 14000      |
# | train/                |            |
# |    entropy_loss       | -8.6       |
# |    explained_variance | 0.00345    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2799       |
# |    policy_loss        | -12.5      |
# |    reward             | 0.90308803 |
# |    std                | 1.02       |
# |    value_loss         | 3.19       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 308        |
# |    iterations         | 2900       |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 14500      |
# | train/                |            |
# |    entropy_loss       | -8.59      |
# |    explained_variance | -0.000105  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2899       |
# |    policy_loss        | -5.15      |
# |    reward             | 0.22395271 |
# |    std                | 1.01       |
# |    value_loss         | 2.5        |
# --------------------------------------
# day: 251, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 3703142.03
# total_reward: 2703142.03
# total_cost: 39909.57
# total_trades: 766
# Sharpe: 2.275
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 309        |
# |    iterations         | 3000       |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 15000      |
# | train/                |            |
# |    entropy_loss       | -8.56      |
# |    explained_variance | 0.00174    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2999       |
# |    policy_loss        | 16.6       |
# |    reward             | -0.4463922 |
# |    std                | 1.01       |
# |    value_loss         | 3.38       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 308        |
# |    iterations         | 3100       |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -8.57      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | -23.5      |
# |    reward             | -1.1616018 |
# |    std                | 1.01       |
# |    value_loss         | 12.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 309        |
# |    iterations         | 3200       |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -8.57      |
# |    explained_variance | 0.000147   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | 10.1       |
# |    reward             | -0.7437382 |
# |    std                | 1.01       |
# |    value_loss         | 3.62       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 310        |
# |    iterations         | 3300       |
# |    time_elapsed       | 53         |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -8.56      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | -13.8      |
# |    reward             | -4.2065296 |
# |    std                | 1.01       |
# |    value_loss         | 9.1        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 311        |
# |    iterations         | 3400       |
# |    time_elapsed       | 54         |
# |    total_timesteps    | 17000      |
# | train/                |            |
# |    entropy_loss       | -8.55      |
# |    explained_variance | -0.000694  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3399       |
# |    policy_loss        | -75        |
# |    reward             | -1.0862566 |
# |    std                | 1.01       |
# |    value_loss         | 62.3       |
# --------------------------------------
# day: 251, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 2588295.73
# total_reward: 1588295.73
# total_cost: 80500.38
# total_trades: 987
# Sharpe: 1.841
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 312       |
# |    iterations         | 3500      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -8.58     |
# |    explained_variance | 7.36e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -0.424    |
# |    reward             | 2.1470122 |
# |    std                | 1.01      |
# |    value_loss         | 7.4       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 311         |
# |    iterations         | 3600        |
# |    time_elapsed       | 57          |
# |    total_timesteps    | 18000       |
# | train/                |             |
# |    entropy_loss       | -8.59       |
# |    explained_variance | 0.000143    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3599        |
# |    policy_loss        | 62.8        |
# |    reward             | -0.04699611 |
# |    std                | 1.01        |
# |    value_loss         | 55.7        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 308      |
# |    iterations         | 3700     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -8.61    |
# |    explained_variance | 3.81e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -56.4    |
# |    reward             | -8.69379 |
# |    std                | 1.02     |
# |    value_loss         | 59.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 309       |
# |    iterations         | 3800      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -8.58     |
# |    explained_variance | 4.45e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 23        |
# |    reward             | 4.2908025 |
# |    std                | 1.01      |
# |    value_loss         | 23.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 310        |
# |    iterations         | 3900       |
# |    time_elapsed       | 62         |
# |    total_timesteps    | 19500      |
# | train/                |            |
# |    entropy_loss       | -8.58      |
# |    explained_variance | 6.98e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3899       |
# |    policy_loss        | -12.9      |
# |    reward             | -2.8237383 |
# |    std                | 1.01       |
# |    value_loss         | 60.9       |
# --------------------------------------
# day: 251, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 4028773.25
# total_reward: 3028773.25
# total_cost: 12831.82
# total_trades: 872
# Sharpe: 2.335
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 311       |
# |    iterations         | 4000      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -8.6      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 113       |
# |    reward             | 6.5398293 |
# |    std                | 1.01      |
# |    value_loss         | 175       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 312        |
# |    iterations         | 4100       |
# |    time_elapsed       | 65         |
# |    total_timesteps    | 20500      |
# | train/                |            |
# |    entropy_loss       | -8.56      |
# |    explained_variance | 0.000107   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4099       |
# |    policy_loss        | 68.1       |
# |    reward             | -1.4470574 |
# |    std                | 1.01       |
# |    value_loss         | 79.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 312       |
# |    iterations         | 4200      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -8.58     |
# |    explained_variance | 7.03e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | 59.1      |
# |    reward             | 0.6670828 |
# |    std                | 1.01      |
# |    value_loss         | 69.2      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 313         |
# |    iterations         | 4300        |
# |    time_elapsed       | 68          |
# |    total_timesteps    | 21500       |
# | train/                |             |
# |    entropy_loss       | -8.58       |
# |    explained_variance | 2.19e-05    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4299        |
# |    policy_loss        | -7.35       |
# |    reward             | 0.080271855 |
# |    std                | 1.01        |
# |    value_loss         | 6.75        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 4400      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -8.6      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -78.7     |
# |    reward             | 4.2885833 |
# |    std                | 1.02      |
# |    value_loss         | 103       |
# -------------------------------------
# day: 251, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 3874445.94
# total_reward: 2874445.94
# total_cost: 6040.60
# total_trades: 982
# Sharpe: 2.275
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 311       |
# |    iterations         | 4500      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -8.57     |
# |    explained_variance | 2.98e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 43.7      |
# |    reward             | 6.7227163 |
# |    std                | 1.01      |
# |    value_loss         | 33.2      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 311         |
# |    iterations         | 4600        |
# |    time_elapsed       | 73          |
# |    total_timesteps    | 23000       |
# | train/                |             |
# |    entropy_loss       | -8.57       |
# |    explained_variance | -1.43e-06   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4599        |
# |    policy_loss        | 22.2        |
# |    reward             | -0.45480233 |
# |    std                | 1.01        |
# |    value_loss         | 9.56        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 312         |
# |    iterations         | 4700        |
# |    time_elapsed       | 75          |
# |    total_timesteps    | 23500       |
# | train/                |             |
# |    entropy_loss       | -8.59       |
# |    explained_variance | 5.42e-05    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4699        |
# |    policy_loss        | -22.6       |
# |    reward             | -0.85232115 |
# |    std                | 1.01        |
# |    value_loss         | 11.4        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 312         |
# |    iterations         | 4800        |
# |    time_elapsed       | 76          |
# |    total_timesteps    | 24000       |
# | train/                |             |
# |    entropy_loss       | -8.57       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4799        |
# |    policy_loss        | 102         |
# |    reward             | -0.51390797 |
# |    std                | 1.01        |
# |    value_loss         | 155         |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 313      |
# |    iterations         | 4900     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -8.56    |
# |    explained_variance | -4.2e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -72.1    |
# |    reward             | 5.641735 |
# |    std                | 1.01     |
# |    value_loss         | 178      |
# ------------------------------------
# day: 251, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 3052754.76
# total_reward: 2052754.76
# total_cost: 67301.72
# total_trades: 966
# Sharpe: 1.891
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 313        |
# |    iterations         | 5000       |
# |    time_elapsed       | 79         |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -8.58      |
# |    explained_variance | -1.07e-05  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -89.5      |
# |    reward             | 0.23545073 |
# |    std                | 1.01       |
# |    value_loss         | 158        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 314       |
# |    iterations         | 5100      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -8.6      |
# |    explained_variance | -0.000386 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 8.59      |
# |    reward             | -38.69717 |
# |    std                | 1.02      |
# |    value_loss         | 1.34      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 314        |
# |    iterations         | 5200       |
# |    time_elapsed       | 82         |
# |    total_timesteps    | 26000      |
# | train/                |            |
# |    entropy_loss       | -8.62      |
# |    explained_variance | 1.5e-05    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5199       |
# |    policy_loss        | -61.7      |
# |    reward             | 0.63305455 |
# |    std                | 1.02       |
# |    value_loss         | 75.5       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 313      |
# |    iterations         | 5300     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -8.62    |
# |    explained_variance | -4.2e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -33.5    |
# |    reward             | 2.798471 |
# |    std                | 1.02     |
# |    value_loss         | 39.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 311      |
# |    iterations         | 5400     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -8.63    |
# |    explained_variance | 5.82e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -16.5    |
# |    reward             | -4.31286 |
# |    std                | 1.02     |
# |    value_loss         | 6.79     |
# ------------------------------------
# day: 251, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 4369025.04
# total_reward: 3369025.04
# total_cost: 10551.75
# total_trades: 916
# Sharpe: 2.455
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 312       |
# |    iterations         | 5500      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -8.62     |
# |    explained_variance | -2.29e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 56.5      |
# |    reward             | -7.231005 |
# |    std                | 1.02      |
# |    value_loss         | 53.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 312       |
# |    iterations         | 5600      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -8.64     |
# |    explained_variance | -7.19e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | 28.5      |
# |    reward             | 1.6762425 |
# |    std                | 1.02      |
# |    value_loss         | 11.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 5700      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -8.64     |
# |    explained_variance | 9.89e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | 61.2      |
# |    reward             | 1.6425152 |
# |    std                | 1.02      |
# |    value_loss         | 80.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 5800      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -8.67     |
# |    explained_variance | -1.25e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -36.6     |
# |    reward             | -2.233995 |
# |    std                | 1.03      |
# |    value_loss         | 31.1      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 5900     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -8.67    |
# |    explained_variance | 1.85e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 34.8     |
# |    reward             | 6.520851 |
# |    std                | 1.03     |
# |    value_loss         | 32.1     |
# ------------------------------------
# day: 251, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 4080947.23
# total_reward: 3080947.23
# total_cost: 3491.03
# total_trades: 1071
# Sharpe: 2.344
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 314        |
# |    iterations         | 6000       |
# |    time_elapsed       | 95         |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -8.68      |
# |    explained_variance | 1.36e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | 6.16       |
# |    reward             | -2.5662234 |
# |    std                | 1.03       |
# |    value_loss         | 4.43       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 314       |
# |    iterations         | 6100      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -8.67     |
# |    explained_variance | -3.39e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -7.47     |
# |    reward             | 10.03425  |
# |    std                | 1.03      |
# |    value_loss         | 211       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 312        |
# |    iterations         | 6200       |
# |    time_elapsed       | 99         |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -8.66      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | 481        |
# |    reward             | -1.1810004 |
# |    std                | 1.03       |
# |    value_loss         | 3.21e+03   |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 6300     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -8.67    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 32.6     |
# |    reward             | 20.53251 |
# |    std                | 1.03     |
# |    value_loss         | 135      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 6400      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -8.67     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 396       |
# |    reward             | 7.2810583 |
# |    std                | 1.03      |
# |    value_loss         | 2.42e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 6500      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -8.66     |
# |    explained_variance | -7.63e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -74.2     |
# |    reward             | 3.2899308 |
# |    std                | 1.03      |
# |    value_loss         | 95.2      |
# -------------------------------------
# day: 251, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 2907080.45
# total_reward: 1907080.45
# total_cost: 29543.18
# total_trades: 828
# Sharpe: 1.857
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 6600      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -8.65     |
# |    explained_variance | -7.27e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | 3.38      |
# |    reward             | 15.798037 |
# |    std                | 1.02      |
# |    value_loss         | 22.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 314        |
# |    iterations         | 6700       |
# |    time_elapsed       | 106        |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -8.64      |
# |    explained_variance | 3.46e-06   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | -23.4      |
# |    reward             | -4.8605776 |
# |    std                | 1.02       |
# |    value_loss         | 121        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 314        |
# |    iterations         | 6800       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -8.62      |
# |    explained_variance | -2.9e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | 123        |
# |    reward             | 0.41718674 |
# |    std                | 1.02       |
# |    value_loss         | 179        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 314        |
# |    iterations         | 6900       |
# |    time_elapsed       | 109        |
# |    total_timesteps    | 34500      |
# | train/                |            |
# |    entropy_loss       | -8.63      |
# |    explained_variance | 3.28e-06   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6899       |
# |    policy_loss        | 135        |
# |    reward             | -5.3039594 |
# |    std                | 1.02       |
# |    value_loss         | 275        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 313        |
# |    iterations         | 7000       |
# |    time_elapsed       | 111        |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -8.62      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 75.7       |
# |    reward             | 0.16747332 |
# |    std                | 1.02       |
# |    value_loss         | 81.7       |
# --------------------------------------
# day: 251, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 3845291.42
# total_reward: 2845291.42
# total_cost: 10073.84
# total_trades: 749
# Sharpe: 2.260
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 312        |
# |    iterations         | 7100       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 35500      |
# | train/                |            |
# |    entropy_loss       | -8.65      |
# |    explained_variance | -8.94e-06  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7099       |
# |    policy_loss        | 140        |
# |    reward             | 0.31849256 |
# |    std                | 1.02       |
# |    value_loss         | 376        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 313        |
# |    iterations         | 7200       |
# |    time_elapsed       | 114        |
# |    total_timesteps    | 36000      |
# | train/                |            |
# |    entropy_loss       | -8.65      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | 3.77       |
# |    reward             | -3.1426756 |
# |    std                | 1.03       |
# |    value_loss         | 6.32       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 7300      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -8.68     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | 66.8      |
# |    reward             | 3.2456965 |
# |    std                | 1.03      |
# |    value_loss         | 93.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 314       |
# |    iterations         | 7400      |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -8.67     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# ...
# |    total_timesteps    | 38000      |
# | train/                |            |
# |    entropy_loss       | -8.66      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7599       |
# |    policy_loss        | 31.5       |
# |    reward             | -3.8714125 |
# |    std                | 1.03       |
# |    value_loss         | 17.6       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 314       |
# |    iterations         | 7700      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -8.67     |
# |    explained_variance | -0.000271 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -16.7     |
# |    reward             | 4.5832434 |
# |    std                | 1.03      |
# |    value_loss         | 10.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 313        |
# |    iterations         | 7800       |
# |    time_elapsed       | 124        |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -8.7       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | 40.9       |
# |    reward             | -1.0261884 |
# |    std                | 1.03       |
# |    value_loss         | 24.7       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 312         |
# |    iterations         | 7900        |
# |    time_elapsed       | 126         |
# |    total_timesteps    | 39500       |
# | train/                |             |
# |    entropy_loss       | -8.7        |
# |    explained_variance | 6.41e-05    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7899        |
# |    policy_loss        | -87.7       |
# |    reward             | -0.47501644 |
# |    std                | 1.03        |
# |    value_loss         | 104         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 312       |
# |    iterations         | 8000      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -8.69     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | 1.64      |
# |    reward             | 3.7030246 |
# |    std                | 1.03      |
# |    value_loss         | 1.68      |
# -------------------------------------
# day: 251, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 1565508.06
# total_reward: 565508.06
# total_cost: 25548.98
# total_trades: 717
# Sharpe: 0.975
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 313        |
# |    iterations         | 8100       |
# |    time_elapsed       | 129        |
# |    total_timesteps    | 40500      |
# | train/                |            |
# |    entropy_loss       | -8.68      |
# |    explained_variance | 0.000523   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8099       |
# |    policy_loss        | -5.88      |
# |    reward             | 0.38923642 |
# |    std                | 1.03       |
# |    value_loss         | 5.45       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 8200      |
# |    time_elapsed       | 130       |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -8.69     |
# |    explained_variance | -0.000177 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | -118      |
# |    reward             | 2.0081348 |
# |    std                | 1.03      |
# |    value_loss         | 249       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 8300      |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -8.67     |
# |    explained_variance | 0.000196  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | -5.64     |
# |    reward             | -4.949251 |
# |    std                | 1.03      |
# |    value_loss         | 7.39      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 8400      |
# |    time_elapsed       | 133       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -8.65     |
# |    explained_variance | -4.66e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -26.5     |
# |    reward             | 4.13976   |
# |    std                | 1.02      |
# |    value_loss         | 10.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 314       |
# |    iterations         | 8500      |
# |    time_elapsed       | 135       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -8.63     |
# |    explained_variance | -0.000106 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | -9.79     |
# |    reward             | 1.3399434 |
# |    std                | 1.02      |
# |    value_loss         | 7.72      |
# -------------------------------------
# day: 251, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 3026031.88
# total_reward: 2026031.88
# total_cost: 89493.29
# total_trades: 815
# Sharpe: 1.968
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 8600      |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -8.64     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -5.14     |
# |    reward             | 1.5988317 |
# |    std                | 1.02      |
# |    value_loss         | 7.75      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 312        |
# |    iterations         | 8700       |
# |    time_elapsed       | 139        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -8.64      |
# |    explained_variance | 2.06e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | 4.18       |
# |    reward             | -0.5453046 |
# |    std                | 1.02       |
# |    value_loss         | 7.96       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 312       |
# |    iterations         | 8800      |
# |    time_elapsed       | 140       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -8.63     |
# |    explained_variance | 0.000316  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | 5.68      |
# |    reward             | 2.5975697 |
# |    std                | 1.02      |
# |    value_loss         | 2.41      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 312        |
# |    iterations         | 8900       |
# |    time_elapsed       | 142        |
# |    total_timesteps    | 44500      |
# | train/                |            |
# |    entropy_loss       | -8.61      |
# |    explained_variance | 5.96e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8899       |
# |    policy_loss        | 126        |
# |    reward             | -1.5328835 |
# |    std                | 1.02       |
# |    value_loss         | 213        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 313      |
# |    iterations         | 9000     |
# |    time_elapsed       | 143      |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -8.59    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | 18.1     |
# |    reward             | 1.759483 |
# |    std                | 1.01     |
# |    value_loss         | 8.53     |
# ------------------------------------
# day: 251, episode: 180
# begin_total_asset: 1000000.00
# end_total_asset: 2969473.51
# total_reward: 1969473.51
# total_cost: 16823.67
# total_trades: 804
# Sharpe: 1.896
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 313        |
# |    iterations         | 9100       |
# |    time_elapsed       | 145        |
# |    total_timesteps    | 45500      |
# | train/                |            |
# |    entropy_loss       | -8.58      |
# |    explained_variance | 0.00315    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9099       |
# |    policy_loss        | -32.5      |
# |    reward             | 0.42357537 |
# |    std                | 1.01       |
# |    value_loss         | 15.5       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 313      |
# |    iterations         | 9200     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -8.61    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | -14.2    |
# |    reward             | 0.263481 |
# |    std                | 1.02     |
# |    value_loss         | 4.59     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 313         |
# |    iterations         | 9300        |
# |    time_elapsed       | 148         |
# |    total_timesteps    | 46500       |
# | train/                |             |
# |    entropy_loss       | -8.61       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9299        |
# |    policy_loss        | 9.56        |
# |    reward             | -0.48808336 |
# |    std                | 1.02        |
# |    value_loss         | 2.85        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 313        |
# |    iterations         | 9400       |
# |    time_elapsed       | 149        |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -8.59      |
# |    explained_variance | -0.00556   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | -43.2      |
# |    reward             | -1.7489464 |
# |    std                | 1.01       |
# |    value_loss         | 33.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 313        |
# |    iterations         | 9500       |
# |    time_elapsed       | 151        |
# |    total_timesteps    | 47500      |
# | train/                |            |
# |    entropy_loss       | -8.59      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9499       |
# |    policy_loss        | 5.27       |
# |    reward             | -0.7897577 |
# |    std                | 1.01       |
# |    value_loss         | 3.64       |
# --------------------------------------
# day: 251, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 3969237.25
# total_reward: 2969237.25
# total_cost: 4063.04
# total_trades: 778
# Sharpe: 2.303
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 312        |
# |    iterations         | 9600       |
# |    time_elapsed       | 153        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -8.58      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -19.6      |
# |    reward             | -4.6951075 |
# |    std                | 1.01       |
# |    value_loss         | 15.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 312        |
# |    iterations         | 9700       |
# |    time_elapsed       | 154        |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -8.56      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | -70.1      |
# |    reward             | -0.9778864 |
# |    std                | 1.01       |
# |    value_loss         | 63.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 9800      |
# |    time_elapsed       | 156       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -8.54     |
# |    explained_variance | 0.00021   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | -12.1     |
# |    reward             | 2.3000097 |
# |    std                | 1.01      |
# |    value_loss         | 13.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 9900      |
# |    time_elapsed       | 157       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -8.52     |
# |    explained_variance | 0.000485  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | 87        |
# |    reward             | 1.4907016 |
# |    std                | 1         |
# |    value_loss         | 137       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 10000     |
# |    time_elapsed       | 159       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -8.52     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | -84.1     |
# |    reward             | -8.368505 |
# |    std                | 1         |
# |    value_loss         | 114       |
# -------------------------------------

# %%
trained_a2c.save(TRAINED_MODEL_DIR + '/agent_a2c') if if_using_a2c else None

# %% [markdown]
# ## Testing

# %%
crypto_dimension_dimention = len(trade.tic.unique())
state_space = 1+ 2*crypto_dimension + len(INDICATORS)*crypto_dimension
print(f"Trade dimension: {crypto_dimension}, State space: {state_space}")
# Out:
# Trade dimension: 6, State space: 61

# %%
buy_cost_list = sell_cost_list = [0.001] * crypto_dimension   # the transaction costs for buying and selling each cryptocurrency
num_crypto_shares = [0] * crypto_dimension

env_kwargs = {
    "hmax": 100,  # maximum number of steps per episode
    "initial_amount": 1000000,  # initial investment amount
    "num_stock_shares": num_crypto_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": crypto_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": crypto_dimension,
    "reward_scaling": 1e-4
}

e_train_gym = StockTradingEnv(df = trade, turbulence_threshold=70, risk_indicator_col='vix', **env_kwargs)

# %%
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(model=trained_a2c,
                                               environment = e_train_gym) if if_using_a2c else (None, None)
# Out:
# hit end!

# %% [markdown]
# ## 3. Backtesing

# %%
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0]) #sets date as index

result = pd.DataFrame()
if if_using_a2c: result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)

# %%
col_name = []
col_name.append('A2C') if if_using_a2c else None
result.columns = col_name

# %%
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
plt.plot(result, marker='o')  # Adjust the plotting methoblob:https://colab.research.google.com/1b32bf29-53b0-4ef7-af20-5f784216aa02d as needed

# Save the plot as an image file
plt.savefig('result_plot.png')  # Save in the current working directory
plt.close()

# %% [markdown]
# ## Mean Variance Optimizatio (MVO)

# %%
#helps us process data into a form for wight calculation

def process_df_for_mvo(df):
    df = df.sort_values(['date', 'tic'], ignore_index=True)[['date','tic', 'close']]
    fst = df
    fst = fst.iloc[0:crypto_dimension, :]
    tic = fst['tic'].tolist()

    mvo = pd.DataFrame()

    for k in range(len(tic)):
     mvo[tic[k]] = 0

    for i in range(df.shape[0]//crypto_dimension):
      n = df
      n = n.iloc[i * crypto_dimension:(i+1) * crypto_dimension, :]
      date = n['date'][i*crypto_dimension]
      mvo.loc[date] = n['close'].tolist()


    return mvo

def crypto_returns_computing(cryptoPrice, rows, columns):
    cryptoReturns = np.zeros((rows-1, columns))
    for j in range(columns):      # j:assets
      for i in range(rows-1):     #i: daily prices
        cryptoReturns[i, j] = (cryptoPrice[i+1, j] - cryptoPrice[i, j])/cryptoPrice[i, j]
    return cryptoReturns

# %%
cryptoData = process_df_for_mvo(train)
tradeData = process_df_for_mvo(trade)

tradeData.to_numpy()

#compute asset returns
arCryptoPrices = np.asarray(cryptoData)
[rows, cols] = arCryptoPrices.shape
arReturns = crypto_returns_computing(arCryptoPrices, rows, cols)

#compute mean returns and variance covariance matrix of returns
meanReturns = np.mean(arReturns, axis=0)
covMatrix = np.cov(arReturns, rowvar=False)

#set percision for printing results
np.set_printoptions(precision=3, suppress = True)

#display mean returns and variance-covariance matrix of returns
print("Mean returns of assets in k-portfolio 1:\n", meanReturns)
print("Variance-covariance matrix of returns:\n", covMatrix)
# Out:
# Mean returns of assets in k-portfolio 1:
#  [0.009 0.005 0.006 0.007 0.009 0.004]
# Variance-covariance matrix of returns:
#  [[0.005 0.004 0.003 0.002 0.004 0.004]
#  [0.004 0.004 0.003 0.002 0.003 0.003]
#  [0.003 0.003 0.003 0.002 0.003 0.002]
#  [0.002 0.002 0.002 0.002 0.002 0.002]
#  [0.004 0.003 0.003 0.002 0.004 0.003]
#  [0.004 0.003 0.002 0.002 0.003 0.007]]

# %%
from pypfopt.efficient_frontier import EfficientFrontier

ef_mean = EfficientFrontier(meanReturns, covMatrix, weight_bounds=(0, 0.5))
raw_weights_mean = ef_mean.max_sharpe(risk_free_rate=0)
cleaned_weights_mean = ef_mean.clean_weights()
mvo_weights = np.array([1000000 * cleaned_weights_mean[i] for i in range(6)])

# %%
lastPrice = np.array([1/p for p in cryptoData.tail(1).to_numpy()[0]])
initialPortfolio = np.multiply(mvo_weights, lastPrice)

portfolio_assets = tradeData @ initialPortfolio
mvo_result = pd.DataFrame(portfolio_assets, columns=['Mean Var'])

mvo_result
# Out:
#                 Mean Var
# 2021-09-01  4.485948e+06
# 2021-09-02  4.523362e+06
# 2021-09-03  4.617061e+06
# 2021-09-07  4.027849e+06
# 2021-09-08  4.037279e+06
# ...                  ...
# 2021-12-22  3.690883e+06
# 2021-12-23  3.877258e+06
# 2021-12-27  3.859129e+06
# 2021-12-28  3.619112e+06
# 2021-12-29  3.468143e+06
#
# [83 rows x 1 columns]

# %%
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0])

result = pd.DataFrame()
if if_using_a2c: result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)

# %%
col_name = []
col_name.append('A2C') if if_using_a2c else None
result.columns = col_name

# %%
result = pd.merge(result, mvo_result, how='outer', left_index=True, right_index=True)
result
# Out:
#                      A2C      Mean Var
# date
# 2021-09-01  1.000000e+06  4.485948e+06
# 2021-09-02  1.008882e+06  4.523362e+06
# 2021-09-03  1.024425e+06  4.617061e+06
# 2021-09-07  9.587516e+05  4.027849e+06
# 2021-09-08  9.440175e+05  4.037279e+06
# ...                  ...           ...
# 2021-12-22  9.873289e+05  3.690883e+06
# 2021-12-23  1.031023e+06  3.877258e+06
# 2021-12-27  1.028446e+06  3.859129e+06
# 2021-12-28  9.665444e+05  3.619112e+06
# 2021-12-29  9.433373e+05  3.468143e+06
#
# [83 rows x 2 columns]

# %%
plt.rcParams["figure.figsize"] = (15, 5)
plt.figure()
plt.plot(result.index, result['A2C'], marker='o', label='a2c')
plt.plot(result.index, result['Mean Var'], marker='o', label='mvo')
plt.legend()  # Add legend based on the labels specified in the plot commands
plt.savefig('combined_result_plot.png')  # Save in the current working directory
plt.close()
